# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from sklearn.datasets import fetch_california_housing

# %%
housing = fetch_california_housing()
housing
# Out:
# {'data': array([[   8.3252    ,   41.        ,    6.98412698, ...,    2.55555556,
#            37.88      , -122.23      ],
#         [   8.3014    ,   21.        ,    6.23813708, ...,    2.10984183,
#            37.86      , -122.22      ],
#         [   7.2574    ,   52.        ,    8.28813559, ...,    2.80225989,
#            37.85      , -122.24      ],
#         ...,
#         [   1.7       ,   17.        ,    5.20554273, ...,    2.3256351 ,
#            39.43      , -121.22      ],
#         [   1.8672    ,   18.        ,    5.32951289, ...,    2.12320917,
#            39.43      , -121.32      ],
#         [   2.3886    ,   16.        ,    5.25471698, ...,    2.61698113,
#            39.37      , -121.24      ]], shape=(20640, 8)),
#  'target': array([4.526, 3.585, 3.521, ..., 0.923, 0.847, 0.894], shape=(20640,)),
#  'frame': None,
#  'target_names': ['MedHouseVal'],
#  'feature_names': ['MedInc',
#   'HouseAge',
#   'AveRooms',
#   'AveBedrms',
#   'Population',
# ...

# %%
feature_names = housing['feature_names']
feature_names
# Out:
# ['MedInc',
#  'HouseAge',
#  'AveRooms',
#  'AveBedrms',
#  'Population',
#  'AveOccup',
#  'Latitude',
#  'Longitude']

# %%
data = housing['data']
data
# Out:
# array([[   8.3252    ,   41.        ,    6.98412698, ...,    2.55555556,
#           37.88      , -122.23      ],
#        [   8.3014    ,   21.        ,    6.23813708, ...,    2.10984183,
#           37.86      , -122.22      ],
#        [   7.2574    ,   52.        ,    8.28813559, ...,    2.80225989,
#           37.85      , -122.24      ],
#        ...,
#        [   1.7       ,   17.        ,    5.20554273, ...,    2.3256351 ,
#           39.43      , -121.22      ],
#        [   1.8672    ,   18.        ,    5.32951289, ...,    2.12320917,
#           39.43      , -121.32      ],
#        [   2.3886    ,   16.        ,    5.25471698, ...,    2.61698113,
#           39.37      , -121.24      ]], shape=(20640, 8))

# %%
target = housing ['target']
target
# Out:
# array([4.526, 3.585, 3.521, ..., 0.923, 0.847, 0.894], shape=(20640,))

# %%
df = pd.DataFrame(data= data, columns=feature_names)
x = df
x
# Out:
#        MedInc  HouseAge  AveRooms  AveBedrms  Population  AveOccup  Latitude  \
# 0      8.3252      41.0  6.984127   1.023810       322.0  2.555556     37.88
# 1      8.3014      21.0  6.238137   0.971880      2401.0  2.109842     37.86
# 2      7.2574      52.0  8.288136   1.073446       496.0  2.802260     37.85
# 3      5.6431      52.0  5.817352   1.073059       558.0  2.547945     37.85
# 4      3.8462      52.0  6.281853   1.081081       565.0  2.181467     37.85
# ...       ...       ...       ...        ...         ...       ...       ...
# 20635  1.5603      25.0  5.045455   1.133333       845.0  2.560606     39.48
# 20636  2.5568      18.0  6.114035   1.315789       356.0  3.122807     39.49
# 20637  1.7000      17.0  5.205543   1.120092      1007.0  2.325635     39.43
# 20638  1.8672      18.0  5.329513   1.171920       741.0  2.123209     39.43
# 20639  2.3886      16.0  5.254717   1.162264      1387.0  2.616981     39.37
#
#        Longitude
# 0        -122.23
# ...

# %%
df['Target'] = target
df
# Out:
#        MedInc  HouseAge  AveRooms  AveBedrms  Population  AveOccup  Latitude  \
# 0      8.3252      41.0  6.984127   1.023810       322.0  2.555556     37.88
# 1      8.3014      21.0  6.238137   0.971880      2401.0  2.109842     37.86
# 2      7.2574      52.0  8.288136   1.073446       496.0  2.802260     37.85
# 3      5.6431      52.0  5.817352   1.073059       558.0  2.547945     37.85
# 4      3.8462      52.0  6.281853   1.081081       565.0  2.181467     37.85
# ...       ...       ...       ...        ...         ...       ...       ...
# 20635  1.5603      25.0  5.045455   1.133333       845.0  2.560606     39.48
# 20636  2.5568      18.0  6.114035   1.315789       356.0  3.122807     39.49
# 20637  1.7000      17.0  5.205543   1.120092      1007.0  2.325635     39.43
# 20638  1.8672      18.0  5.329513   1.171920       741.0  2.123209     39.43
# 20639  2.3886      16.0  5.254717   1.162264      1387.0  2.616981     39.37
#
#        Longitude  Target
# ...

# %%
df.shape
# Out:
# (20640, 9)

# %%
from sklearn.model_selection import train_test_split
X_train,X_test,y_train,y_test=train_test_split(x,target , test_size=0.1, random_state=1)

# %%
X_train
# Out:
#        MedInc  HouseAge  AveRooms  AveBedrms  Population  AveOccup  Latitude  \
# 5425   4.9676      34.0  5.430993   1.075061       973.0  2.355932     34.02
# 12499  3.1583      52.0  5.364238   1.139073       326.0  2.158940     38.57
# 7020   2.9922      35.0  4.719844   1.029183      2010.0  3.910506     33.97
# 6477   3.7066      32.0  4.279627   0.956059      2316.0  3.083888     34.09
# 8670   4.5687      32.0  4.622332   0.996716      1338.0  2.197044     33.82
# ...       ...       ...       ...        ...         ...       ...       ...
# 10955  1.7823      17.0  4.055046   1.087156      1079.0  2.474771     33.76
# 17289  8.5608      42.0  6.788462   1.011538       753.0  2.896154     34.42
# 5192   1.1326      42.0  4.890785   1.006826       775.0  2.645051     33.93
# 12172  2.6322      10.0  4.991614   0.951782      1323.0  2.773585     33.73
# 235    2.3036      35.0  4.620513   1.176923      1009.0  2.587179     37.79
#
#        Longitude   Target
# ...

# %%
X_test
# Out:
#        MedInc  HouseAge   AveRooms  AveBedrms  Population  AveOccup  Latitude  \
# 4712   3.2500      39.0   4.503205   1.073718      1109.0  1.777244     34.06
# 2151   1.9784      37.0   4.988584   1.038813      1143.0  2.609589     36.78
# 15927  4.0132      46.0   4.480296   1.012315      1534.0  3.778325     37.73
# 82     1.5208      52.0   3.908046   1.114943       200.0  2.298851     37.81
# 8161   5.1795      37.0   5.406360   1.024735       711.0  2.512367     33.82
# ...       ...       ...        ...        ...         ...       ...       ...
# 8567   4.5743      28.0   4.881230   1.053022      2191.0  2.323436     33.93
# 17969  3.6990      19.0   3.532110   1.073394      2672.0  2.042813     37.32
# 12376  4.0360       5.0  13.885901   2.851017      2880.0  2.093023     33.75
# 8019   3.7813      36.0   6.634615   1.048077       316.0  3.038462     33.84
# 13061  4.0938      29.0   5.721973   1.008969       600.0  2.690583     38.60
#
#        Longitude  Target
# ...

# %%
y_train
# Out:
# array([4.141, 1.4  , 1.635, ..., 1.048, 1.407, 1.26 ], shape=(18576,))

# %%
y_test
# Out:
# array([3.55 , 0.707, 2.294, ..., 1.585, 2.091, 1.091], shape=(2064,))

# %%
from sklearn.linear_model import LinearRegression
lr = LinearRegression()
lr.fit(X_train,y_train)
# Out:
# LinearRegression()

# %%
lr.score(X_train, y_train)
# Out:
# 1.0

# %%
lr.score(X_test,y_test)
# Out:
# 1.0

# %%
from sklearn.ensemble import RandomForestRegressor
rfg = RandomForestRegressor(n_estimators=11)
rfg.fit(X_train,y_train)
# Out:
# RandomForestRegressor(n_estimators=11)

# %%
rfg.score(X_train, y_train)
# Out:
# 0.999999914198802

# %%
rfg.score(X_test,y_test)
# Out:
# 0.9999997404474775

# %%
rfg.predict([[8.32,41.0,6.98,1.023,322.0,2.55,37.88,-122.23]])
# Out:
# C:\Users\Abdul\anaconda3\Lib\site-packages\sklearn\utils\validation.py:2749: UserWarning: X does not have valid feature names, but RandomForestRegressor was fitted with feature names
#   warnings.warn(
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[20], line 1
# ----> 1 rfg.predict([[8.32,41.0,6.98,1.023,322.0,2.55,37.88,-122.23]])
#
# File ~\anaconda3\Lib\site-packages\sklearn\ensemble\_forest.py:1065, in ForestRegressor.predict(self, X)
#    1063 check_is_fitted(self)
#    1064 # Check data
# -> 1065 X = self._validate_X_predict(X)
#    1067 # Assign chunk of trees to jobs
#    1068 n_jobs, _, _ = _partition_estimators(self.n_estimators, self.n_jobs)
#
# File ~\anaconda3\Lib\site-packages\sklearn\ensemble\_forest.py:637, in BaseForest._validate_X_predict(self, X)
#     634 else:
#     635     ensure_all_finite = True
# --> 637 X = validate_data(
# ...

# %%
rfg.predict([[8.32,41.0,6.98,1.023,322.0,2.55,37.88,-122.23]])

# %%
import pickle
pickle.dump(rfg, open('regressor.pkl', 'wb'))

# %%
model = pickle.load(open('regressor.pkl','rb'))

# %%
model.predict([[8.32,41.0,6.98,1.023,322.0,2.55,37.88,-122.23]])

# %%
{
  "MedInc": 8.3252,
  "HouseAge": 41,
  "AveRooms": 6.984127,
  "AveBedrms": 1.023810,
  "Population": 322,
  "AveOccup": 2.555556,
  "Latitude": 37.88,
  "Longitude": -122.23
}
